# %%
from Algorithms.Z_algorithm import get_matches as Z
from Algorithms.manacher import manacher as M

import os

# %%
# Clase principal
class Virus:
  def __init__(self, file_path):
    if not os.path.exists(file_path):
      raise FileNotFoundError(f"El archivo {file_path} no existe")
    with open(file_path, 'r') as file:
      lines = file.readlines()
    self.metadata = lines[0].strip()
    self.sequence = ''.join(line.strip() for line in lines[1:])
    self.file = os.path.basename(file_path)
    self.palindromo = M(self.sequence) # Algoritmo Manacher importado
    
    new_sequence = ''
    # Iterar por la longitud de la secuencia con un salto de 3 (cada codon)
    for i in range(0, len(self.sequence), 3):  
        codon = self.sequence[i:i+3]
        amino_acid = self.codon_to_amino_acid.get(codon, '?')  # '?' si no encuentra
        new_sequence += amino_acid
    self.amino_sequence = new_sequence

  def getFirstChars(self, n=12):
    if n > len(self.sequence):
      raise ValueError("n no puede ser mayor a la longitud de la secuencia (length =", len(self.sequence), ")")
    return self.sequence[:n]
  
  codon_to_amino_acid = {
    'GCT': 'A', 'GCC': 'A', 'GCA': 'A', 'GCG': 'A',  # Alanine
    'CGT': 'R', 'CGC': 'R', 'CGA': 'R', 'CGG': 'R', 'AGA': 'R', 'AGG': 'R',  # Arginine
    'AAT': 'N', 'AAC': 'N',  # Asparagine
    'GAT': 'D', 'GAC': 'D',  # Aspartic Acid
    'TGT': 'C', 'TGC': 'C',  # Cysteine
    'CAA': 'Q', 'CAG': 'Q',  # Glutamine
    'GAA': 'E', 'GAG': 'E',  # Glutamic Acid
    'GGT': 'G', 'GGC': 'G', 'GGA': 'G', 'GGG': 'G',  # Glycine
    'CAT': 'H', 'CAC': 'H',  # Histidine
    'ATT': 'I', 'ATC': 'I', 'ATA': 'I',  # Isoleucine
    'TTA': 'L', 'TTG': 'L', 'CTT': 'L', 'CTC': 'L', 'CTA': 'L', 'CTG': 'L',  # Leucine
    'AAA': 'K', 'AAG': 'K',  # Lysine
    'ATG': 'M',  # Methionine (Start)
    'TTT': 'F', 'TTC': 'F',  # Phenylalanine
    'CCT': 'P', 'CCC': 'P', 'CCA': 'P', 'CCG': 'P',  # Proline
    'TCT': 'S', 'TCC': 'S', 'TCA': 'S', 'TCG': 'S', 'AGT': 'S', 'AGC': 'S',  # Serine
    'ACT': 'T', 'ACC': 'T', 'ACA': 'T', 'ACG': 'T',  # Threonine
    'TGG': 'W',  # Tryptophan
    'TAT': 'Y', 'TAC': 'Y',  # Tyrosine
    'GTT': 'V', 'GTC': 'V', 'GTA': 'V', 'GTG': 'V',  # Valine
    'TAA': '*', 'TAG': '*', 'TGA': '*'  # Stop 
  } 

  def printData(self):
    print("File: ", self.file)
    print("Metadata: ", self.metadata)
    #print("Sequence: ", self.sequence)
    print("Primeros 12 chars: ", self.getFirstChars())
    print("Palindromo: ", self.palindromo)

# %%
class Gen(Virus):
  def __init__(self, file_path):
    super().__init__(file_path)
    self.VirusIndexes = []

  def check_viruses(self, viruses):
    for virus in viruses:
      self.VirusIndexes.append([virus.file, Z(self.sequence, virus.sequence)])

  def printData(self):
    super().printData()
    for virus in self.VirusIndexes:
      print("Virus: ", virus[0])
      print("Indexes: ", virus[1])

# %%
class Proteina(Virus):
  def __init__(self, metadata, sequence, file_path):
    self.file = os.path.basename(file_path)
    self.metadata = metadata
    self.sequence = sequence
    self.palindromo = M(self.sequence)  # Manacher function or similar
    self.VirusIndexes = []
    self.GeneIndexes = []

  @classmethod
  def leer_de_mismo_archivo(cls, file_path):
    if not os.path.exists(file_path):
      raise FileNotFoundError(f"El archivo {file_path} no existe")

    with open(file_path, 'r') as file:
      content = file.read().split('>')  # Split by '>' to separate different proteins

      proteins = []
      for entry in content:
        if entry.strip():
          lines = entry.splitlines()
          metadata = lines[0].strip()
          sequence = ''.join(line.strip() for line in lines[1:])
          protein = cls(metadata, sequence, file_path)  # Create Proteina instances
          proteins.append(protein)

      return proteins
  
  # Sobreescribir porque ahora se busca con el amino_sequence
  def check_viruses(self, viruses):
    for virus in viruses:
      self.VirusIndexes.append([virus.file, Z(self.sequence, virus.amino_sequence)])
  
  def check_genes(self, genes):
    for gene in genes:
      self.GeneIndexes.append([gene.file, Z(self.sequence, gene.amino_sequence)])

  def printData(self):
    print("Metadata: ", self.metadata)
    #print("Sequence: ", self.sequence)
    print("Primeros 12 chars: ", self.getFirstChars())
    print("Palindromo: ", self.palindromo)
    for virus in self.VirusIndexes:
      print("Virus: ", virus[0])
      print("Indexes: ", virus[1])
    for gene in self.GeneIndexes:
      print("Gene: ", gene[0])
      print("Indexes: ", gene[1])

# %%
def leer_archivos_de_directorio(directory, tipo):
    sequences = []
    for filename in os.listdir(directory):
      if filename.endswith('.txt'):
        file_path = os.path.join(directory, filename)
        if tipo == 1:
          sequences.append(Virus(file_path))
        elif tipo == 2:
          sequences.append(Gen(file_path))
        elif tipo == 3:
          # Aqui es extend porque regresa una lista de objetos y no un objeto (y se rquiere una lista de objetos plana)
          sequences.extend(Proteina.leer_de_mismo_archivo(file_path))
        else:
          raise ValueError("Tipo no valido")
    return sequences

# %%
path_genes = 'genes'
path_viruses = 'viruses'
path_proteinas = 'proteinas'
viruses = leer_archivos_de_directorio(path_viruses, 1)
genes = leer_archivos_de_directorio(path_genes, 2)
proteinas = leer_archivos_de_directorio(path_proteinas, 3)

print("-----------------------")
print("\nVIRUS DATA\n")
print("-----------------------\n")
for virus in viruses:
    virus.printData()
    print()

print("-----------------------")
print("\nGENE DATA\n")
print("-----------------------\n")

for gen in genes:
    gen.check_viruses(viruses)
    gen.printData()
    print()

print("-----------------------")
print("\nPROTEIN DATA\n")
print("-----------------------\n")

for proteina in proteinas:
    proteina.check_viruses(viruses)
    proteina.check_genes(genes)
    proteina.printData()
    print()
# Out:
# -----------------------
#
# VIRUS DATA
#
# -----------------------
#
# File:  SARS-COV-2-MN908947.3.txt
# Metadata:  >MN908947.3 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome
# Primeros 12 chars:  ATTAAAGGTTTA
# Palindromo:  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#
# File:  SARS-COV-2-MT106054.1.txt
# Metadata:  >MT106054.1 Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/USA/TX-CDC-03050000-001/2020, complete genome
# Primeros 12 chars:  ATTAAAGGTTTA
# Palindromo:  CTCAATGACTTCAGTAACTC
#
# -----------------------
#
# GENE DATA
#
# -----------------------
#
# File:  gen-M.txt
# Metadata:  >MN908947.3:26523-27191 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome
# Primeros 12 chars:  ATGGCAGATTCC
# Palindromo:  CTAAAGAAATC
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [26522]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [26522]
#
# File:  gen-ORF1AB.txt
# Metadata:  >MN908947.3:266-21555 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome
# Primeros 12 chars:  ATGGAGAGCCTT
# Palindromo:  CTCAATGACTTCAGTAACTC
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [265]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
#
# File:  gen-S.txt
# Metadata:  >MN908947.3:21563-25384 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome
# Primeros 12 chars:  ATGTTTGTTTTT
# Palindromo:  ATTTTGGTGGTTTTA
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [21562]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [21562]
#
# -----------------------
#
# PROTEIN DATA
#
# -----------------------
#
# Metadata:  QHD43415_1
# Primeros 12 chars:  MESLVPGFNEKT
# Palindromo:  KNGNK
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [0]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_2
# Primeros 12 chars:  AYTRYVDNNFCG
# Palindromo:  AKLKA
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [180]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_3
# Primeros 12 chars:  APTKVTFGDDTV
# Palindromo:  VNAANV
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [818]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_4
# Primeros 12 chars:  KIVNNWLKQLIK
# Palindromo:  LAKAL
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [2763]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_5
# Primeros 12 chars:  SGFRKMAFPSGK
# Palindromo:  GSPSG
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [3263]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_6
# Primeros 12 chars:  SAVKRTIKGTHH
# Palindromo:  VLTLV
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [3569]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_7
# Primeros 12 chars:  SKMSDVKCTSVV
# Palindromo:  VSLLSV
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [3859]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_8
# Primeros 12 chars:  AIASEFSSLPSY
# Palindromo:  NNIINN
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [3942]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_9
# Primeros 12 chars:  NNELSPVALRQM
# Palindromo:  LNNL
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [4140]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_10
# Primeros 12 chars:  AGNATEVPANST
# Palindromo:  CSC
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  [4253]
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_11
# Primeros 12 chars:  SADAQSFLNRVC
# Palindromo:  TNDNT
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_12
# Primeros 12 chars:  AVGACVLCNSQT
# Palindromo:  ARLRA
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [5412]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [5412]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_13
# Primeros 12 chars:  AENVTGLFKDCS
# Palindromo:  TKFKT
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [6013]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_14
# Primeros 12 chars:  SLENVAFNVVNK
# Palindromo:  DLLLD
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [6540]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [6540]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43415_15
# Primeros 12 chars:  SSQAWQPGVAMP
# Palindromo:  SDADS
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [6886]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [6886]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43416
# Primeros 12 chars:  MFVFLVLLPLVS
# Palindromo:  ADTTDA
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  [0]
#
# Metadata:  QHD43417
# Primeros 12 chars:  MDLFMRIFTIGT
# Palindromo:  VALLAV
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [8464]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [8464]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43418
# Primeros 12 chars:  MYSFVSEETGTL
# Palindromo:  FVVF
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [8748]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [8748]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43419
# Primeros 12 chars:  MADSNGTITVEE
# Palindromo:  LESEL
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  [0]
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43420
# Primeros 12 chars:  MFHLVDFQVTIA
# Palindromo:  LSKSL
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [9067]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [9067]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43421
# Primeros 12 chars:  MKIILFLALITL
# Palindromo:  KRK
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  [9131]
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  [9131]
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43422
# Primeros 12 chars:  MKFLVFLGIITT
# Palindromo:  VRV
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHD43423
# Primeros 12 chars:  MSDNGPQNQRNA
# Palindromo:  SRSSSRS
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []
#
# Metadata:  QHI42199
# Primeros 12 chars:  MGYINVFAFPFT
# Palindromo:  NFN
# Virus:  SARS-COV-2-MN908947.3.txt
# Indexes:  []
# Virus:  SARS-COV-2-MT106054.1.txt
# Indexes:  []
# Gene:  gen-M.txt
# Indexes:  []
# Gene:  gen-ORF1AB.txt
# Indexes:  []
# Gene:  gen-S.txt
# Indexes:  []

# %%
virus_map = {}
virusIndex = 0
for virus in viruses:
    virus_map[virus.file] = []
    for gene in genes:
        if len(gene.VirusIndexes[virusIndex][1]) > 0:
            virus_map[virus.file].append((gene.file, gene.VirusIndexes[virusIndex][1]))
    virusIndex += 1
print(virus_map)

gene_map = {}
geneIndex = 0
for gene in genes:
    gene_map[gene.file] = []
    for proteina in proteinas:
        if len(proteina.GeneIndexes[geneIndex][1]) > 0:
            gene_map[gene.file].append((proteina.metadata, proteina.GeneIndexes[geneIndex][1]))
    geneIndex += 1
print(gene_map)
# Out:
# {'SARS-COV-2-MN908947.3.txt': [('gen-M.txt', [26522]), ('gen-ORF1AB.txt', [265]), ('gen-S.txt', [21562])], 'SARS-COV-2-MT106054.1.txt': [('gen-M.txt', [26522]), ('gen-S.txt', [21562])]}
# {'gen-M.txt': [('QHD43419', [0])], 'gen-ORF1AB.txt': [('QHD43415_1', [0]), ('QHD43415_2', [180]), ('QHD43415_3', [818]), ('QHD43415_4', [2763]), ('QHD43415_5', [3263]), ('QHD43415_6', [3569]), ('QHD43415_7', [3859]), ('QHD43415_8', [3942]), ('QHD43415_9', [4140]), ('QHD43415_10', [4253])], 'gen-S.txt': [('QHD43416', [0])]}

# %%
# Print virus map with better formatting
print("Mapeo de virus a gen:")
for virus, genes in virus_map.items():
    print(f"\n{virus}:")
    for gene, index in genes:
        print(f"  - {gene} en indice {index}")

# Print gene map with better formatting
print("\nMapeo de proteina a gen:")
for gene, proteins in gene_map.items():
    print(f"\n{gene}:")
    for protein, index in proteins:
        print(f"  - Proteina {protein} en indice {index}")
# Out:
# Mapeo de virus a gen:
#
# SARS-COV-2-MN908947.3.txt:
#   - gen-M.txt en indice [26522]
#   - gen-ORF1AB.txt en indice [265]
#   - gen-S.txt en indice [21562]
#
# SARS-COV-2-MT106054.1.txt:
#   - gen-M.txt en indice [26522]
#   - gen-S.txt en indice [21562]
#
# Mapeo de proteina a gen:
#
# gen-M.txt:
#   - Proteina QHD43419 en indice [0]
#
# gen-ORF1AB.txt:
#   - Proteina QHD43415_1 en indice [0]
#   - Proteina QHD43415_2 en indice [180]
#   - Proteina QHD43415_3 en indice [818]
#   - Proteina QHD43415_4 en indice [2763]
#   - Proteina QHD43415_5 en indice [3263]
#   - Proteina QHD43415_6 en indice [3569]
#   - Proteina QHD43415_7 en indice [3859]
#   - Proteina QHD43415_8 en indice [3942]
#   - Proteina QHD43415_9 en indice [4140]
#   - Proteina QHD43415_10 en indice [4253]
#
# gen-S.txt:
#   - Proteina QHD43416 en indice [0]
